# %% [markdown]
# # 4. Load variables from json data
# ## Let's load different experimental data
#
# ![graph](images/j.PNG)

# %% [markdown]
# # Initialize module

# %%
#add library path if necessary
import sys
sys.path.append("../../FlowMater/")

#load module
from ExperimentManager import ExperimentManager

# %%
# automatically load and parse data in the database folder

#path to the database folder (you can use wild cards, such as *)
base_path="database/*/**"

#path to the keyword file
json_path="database/lot_keywords.json"

#load graph data
experiment_manager = ExperimentManager(base_path=base_path,json_path=json_path)
# %time experiment_manager.auto_load()
# Out:
# load already parsed database
# Wall time: 33 ms

# %%
import pandas as pd
#automatically converted dataframe
df=experiment_manager.dataframe

# %%
#drop duplicate data

#"label: ..." columns show fingerprints showing the characteristics of experiments, (connections to the nearest neighbouring nodes are considered)
# "FP: ..." columns are their compressed version
smart_df=df.loc[:,~(df.nunique()==1)]
smart_df
# Out:
#                                                    strength_strength  \
# normal_experiment0_graph_integrated_json_0_data...             5 MPa
# normal_experiment0_graph_integrated_json_1_data...            15 MPa
# normal_experiment0_graph_integrated_json_2_data...            20 MPa
# normal_experiment0_graph_integrated_json_3_data...            30 MPa
#
#                                                    heat_temperature_temperature  \
# normal_experiment0_graph_integrated_json_0_data...                        40 oC
# normal_experiment0_graph_integrated_json_1_data...                        50 oC
# normal_experiment0_graph_integrated_json_2_data...                        60 oC
# normal_experiment0_graph_integrated_json_3_data...                        70 oC
#
#                                                    label: Heat, type: procedure, temperature: 40 oC, time: 10 min, <-->Mix--Mix--Sample  \
# normal_experiment0_graph_integrated_json_0_data...                                                  1
# normal_experiment0_graph_integrated_json_1_data...                                                  0
# normal_experiment0_graph_integrated_json_2_data...                                                  0
# normal_experiment0_graph_integrated_json_3_data...                                                  0
#
#                                                    label: Heat, type: procedure, temperature: 60 oC, time: 10 min, <-->Mix--Mix--Sample  \
# normal_experiment0_graph_integrated_json_0_data...                                                  0
# normal_experiment0_graph_integrated_json_1_data...                                                  0
# normal_experiment0_graph_integrated_json_2_data...                                                  1
# normal_experiment0_graph_integrated_json_3_data...                                                  0
#
#                                                    label: Heat, type: procedure, temperature: 70 oC, time: 10 min, <-->Mix--Mix--Sample  \
# normal_experiment0_graph_integrated_json_0_data...                                                  0
# normal_experiment0_graph_integrated_json_1_data...                                                  0
# normal_experiment0_graph_integrated_json_2_data...                                                  0
# normal_experiment0_graph_integrated_json_3_data...                                                  1
#
#                                                    label: Heat, type: procedure, temperature: 50 oC, time: 10 min, <-->Mix--Mix--Sample  \
# normal_experiment0_graph_integrated_json_0_data...                                                  0
# normal_experiment0_graph_integrated_json_1_data...                                                  1
# normal_experiment0_graph_integrated_json_2_data...                                                  0
# normal_experiment0_graph_integrated_json_3_data...                                                  0
#
#                                                    FP: Heat-temperature-40oC-10min-|Mix-Sample-  \
# normal_experiment0_graph_integrated_json_0_data...                                            1
# normal_experiment0_graph_integrated_json_1_data...                                            0
# normal_experiment0_graph_integrated_json_2_data...                                            0
# normal_experiment0_graph_integrated_json_3_data...                                            0
#
#                                                    FP: Heat-temperature-70oC-10min-|Mix-Sample-  \
# normal_experiment0_graph_integrated_json_0_data...                                            0
# normal_experiment0_graph_integrated_json_1_data...                                            0
# normal_experiment0_graph_integrated_json_2_data...                                            0
# normal_experiment0_graph_integrated_json_3_data...                                            1
#
#                                                    FP: Heat-temperature-50oC-10min-|Mix-Sample-  \
# normal_experiment0_graph_integrated_json_0_data...                                            0
# normal_experiment0_graph_integrated_json_1_data...                                            1
# normal_experiment0_graph_integrated_json_2_data...                                            0
# normal_experiment0_graph_integrated_json_3_data...                                            0
#
#                                                    FP: Heat-temperature-60oC-10min-|Mix-Sample-
# normal_experiment0_graph_integrated_json_0_data...                                            0
# normal_experiment0_graph_integrated_json_1_data...                                            0
# normal_experiment0_graph_integrated_json_2_data...                                            1
# normal_experiment0_graph_integrated_json_3_data...                                            0

# %%
#make custom dataframe
custom_df=pd.DataFrame()
custom_df["Heat temperature [oC]"]=smart_df["heat_temperature_temperature"].str.replace(" oC","").astype(float)
custom_df["Property [MPa]"]=smart_df["strength_strength"].str.replace(" MPa","").astype(float)
custom_df
# Out:
#                                                     Heat temperature [oC]  \
# normal_experiment0_graph_integrated_json_0_data...                   40.0
# normal_experiment0_graph_integrated_json_1_data...                   50.0
# normal_experiment0_graph_integrated_json_2_data...                   60.0
# normal_experiment0_graph_integrated_json_3_data...                   70.0
#
#                                                     Property [MPa]
# normal_experiment0_graph_integrated_json_0_data...             5.0
# normal_experiment0_graph_integrated_json_1_data...            15.0
# normal_experiment0_graph_integrated_json_2_data...            20.0
# normal_experiment0_graph_integrated_json_3_data...            30.0
